# %%
import pandas as pd

# %%
pd read_csv("http://www.firstpythonnotebook.org/_static/committees.csv")
# Out:
#   File "<ipython-input-51-e0ed709db102>", line 1
#     pd read_csv("http://www.firstpythonnotebook.org/_static/committees.csv")
#               ^
# SyntaxError: invalid syntax

# %%
props = pd.read_csv("http://www.firstpythonnotebook.org/_static/committees.csv")

# %%
contribs = pd.read_csv("http://www.firstpythonnotebook.org/_static/contributions.csv")

# %%
props.prop_name.value_counts()

# %%
prop = props[props.prop_name == "PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-12 SCHOOL AND COMMUNITY COLLEGE FACILITIES. INITIATIVE STATUTORY AMENDMENT."]

# %%
prop.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
#
#    ccdc_prop_id                                          prop_name  \
# 0            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                382                 1374469
# 1                383                 1220380
# 2                384                 1282321
# 3                385                 1382843
#
# ...

# %%
prop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4 entries, 0 to 3
# Data columns (total 8 columns):
# ocd_prop_id               4 non-null object
# calaccess_prop_id         4 non-null int64
# ccdc_prop_id              4 non-null int64
# prop_name                 4 non-null object
# ccdc_committee_id         4 non-null int64
# calaccess_committee_id    4 non-null int64
# committee_name            4 non-null object
# committee_position        4 non-null object
# dtypes: int64(4), object(4)
# memory usage: 224.0+ bytes

# %%
contribs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56379 entries, 0 to 56378
# Data columns (total 13 columns):
# calaccess_committee_id          56379 non-null int64
# committee_name                  56379 non-null object
# calaccess_filing_id             56379 non-null int64
# date_received                   56379 non-null object
# contributor_lastname            56375 non-null object
# contributor_firstname           53411 non-null object
# contributor_city                56369 non-null object
# contributor_state               56363 non-null object
# contributor_zip                 56366 non-null object
# contributor_employer            48572 non-null object
# contributor_occupation          53273 non-null object
# contributor_is_self_employed    56379 non-null bool
# amount                          56379 non-null float64
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 3.3+ MB

# %%
merged = pd.merge(prop, contribs, on="calaccess_committee_id")

# %%
merged.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
#
#    ccdc_prop_id                                          prop_name  \
# 0            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                382                 1374469
# ...

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1538 entries, 0 to 1537
# Data columns (total 20 columns):
# ocd_prop_id                     1538 non-null object
# calaccess_prop_id               1538 non-null int64
# ccdc_prop_id                    1538 non-null int64
# prop_name                       1538 non-null object
# ccdc_committee_id               1538 non-null int64
# calaccess_committee_id          1538 non-null int64
# committee_name_x                1538 non-null object
# committee_position              1538 non-null object
# committee_name_y                1538 non-null object
# calaccess_filing_id             1538 non-null int64
# date_received                   1538 non-null object
# contributor_lastname            1538 non-null object
# contributor_firstname           66 non-null object
# contributor_city                1538 non-null object
# contributor_state               1538 non-null object
# contributor_zip                 1538 non-null object
# ...

# %%
merged.amount.sum()
# Out:
# 12987942.84

# %%
merged.committee_position.value_counts()
# Out:
# SUPPORT    1538
# Name: committee_position, dtype: int64

# %%
support = merged[merged.committee_position == "SUPPORT"]

# %%
oppose = merged[merged.committee_position == "OPPOSE"]

# %%
support.amount.sum()
# Out:
# 12987942.84

# %%
oppose.amount.sum()
# Out:
# 0

# %%
support.amount.sum() / merged.amount.sum()
# Out:
# 1.0

# %%
support.amount.sum() / merged.amount.sum() * 100
# Out:
# 100.0

# %%
merged.sort_values("amount", ascending=False)
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 236  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 279  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 225  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 228  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 71   ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 118  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 66   ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 662  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 499  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 84   ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 511  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2    ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# ...

# %%
oppose.sort_values("amount", ascending=False).head(10)
# Out:
# Empty DataFrame
# Columns: [ocd_prop_id, calaccess_prop_id, ccdc_prop_id, prop_name, ccdc_committee_id, calaccess_committee_id, committee_name_x, committee_position, committee_name_y, calaccess_filing_id, date_received, contributor_lastname, contributor_firstname, contributor_city, contributor_state, contributor_zip, contributor_employer, contributor_occupation, contributor_is_self_employed, amount]
# Index: []

# %%
merged.groupby("committee_name_x").amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#                                     committee_name_x       amount
# 2  YES ON PROPOSITION 51 - CALIFORNIANS FOR QUALI...  11880644.00
# 0  COMMUNITY COLLEGE FACILITY COALITION ISSUES CO...   1062548.84
# 1  TORLAKSON'S INVEST IN CALIFORNIA A BALLOT MEAS...     44750.00

# %%
merged.groupby(["contributor_lastname", "committee_position"]).amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#                                   contributor_lastname committee_position  \
# 180  COALITION FOR ADEQUATE SCHOOL HOUSING ISSUES C...            SUPPORT
# 125  CALIFORNIA BUILDING INDUSTRY ASSOCIATION ISSUE...            SUPPORT
# 461  LEWIS PACIFIC PARTNERS, INCLUDING CONTRIBUTION...            SUPPORT
# 118    CALATLANTIC GROUP, INC. AND AFFILIATED ENTITIES            SUPPORT
# 187  COMMUNITY COLLEGE FACILITY COALITION ISSUES CO...            SUPPORT
# 123  CALIFORNIA ASSOCIATION OF REALTORS ISSUES MOBI...            SUPPORT
# 457  LENNAR HOMES OF CALIFORNIA INC., AND AFFILIATE...            SUPPORT
# 792                             TRI POINTE HOMES, INC.            SUPPORT
# 399                               J. F. SHEA CO., INC.            SUPPORT
# 418                                            KB HOME            SUPPORT
# 749                              TAYLOR MORRISON, INC.            SUPPORT
# 648                           RMV PA2 DEVELOPMENT, LLC            SUPPORT
# ...
